# %%
print('Hola Mundo')
#este es un comentario
# Out:
# Hola Mundo

# %%
import numpy as np   #biblioteca numpy orientda a calculos matriciales yfunciones matemáticas
R=4;
print('El valor de R es: ',R)

#crear arreglo
Ar=np.zeros((5,1));
Ar[3][0]=1.5;  #asignar valor a un elemento
print('El arreglo creado es: ')
print(Ar)

#crear matriz
Matriz=np.zeros((5,7));
Matriz[0][3]=45;  #asignar valor a un elemento
print('La matriz creada es:')
print(Matriz)

# %%
#ciclos for
for i in range(9):
   print(i)

   if (i>=7) :
     print('***')
   else:
     print('--')


print('Fin del ciclo')

# %%
#leer entrada del teclado
V=input('Introduce un valor entero y despues <Enter>: ')
valor=int (V); #convertir entrada tipo texto a entero
print('se introdujo: ',valor,'+ 5 =', valor+5);
